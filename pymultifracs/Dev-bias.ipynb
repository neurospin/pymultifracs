# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pymultifracs import wavelet_analysis, mfa
from pymultifracs.simul import mrw, fbm
import matplotlib.pyplot as plt
import numpy as np

# %%
X = mrw((2**15, 1000), .8, .22)
WTpL = wavelet_analysis(X).get_leaders(2)

# %%
X = fbm((2**15, 100), .8)
WTpL = wavelet_analysis(X).get_leaders(2)

# %%
pwt = mfa(WTpL, [(6, 11)], bias_correction=False, n_cumul=4, weighted='Nj')

# %%
pwt_corr = mfa(WTpL, [(6, 11)], bias_correction=True, n_cumul=4, weighted='Nj')

# %%
pwt.cumulants.c2.mean()
# Out:
# <xarray.DataArray ()> Size: 8B
# array(-0.05332334)
# Coordinates:
#     m        int64 8B 2

# %%
pwt_corr.cumulants.c2.mean()
# Out:
# <xarray.DataArray ()> Size: 8B
# array(-0.05096226)
# Coordinates:
#     m        int64 8B 2

# %%
pwt.cumulants.plot()

# %%
pwt_corr.cumulants.plot()
